# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid")
rs = np.random.RandomState(10)

# %%
(lambda __g: [[[[None for __g['g'] in [(sns.jointplot(x, y, kind='hex', height=7, space=0))]][0] for __g['y'] in [(pd.Series(y, name='$Y_1$'))]][0] for __g['x'] in [(pd.Series(x, name='$X_1$'))]][0] for (__g['x'], __g['y']) in [(rs.multivariate_normal([0, 0], [(1, 0.5), (0.5, 1)], 500).T)]][0])(globals())
